# %% [markdown]
# <a href="https://colab.research.google.com/github/nvignesh05/Text-Summarizer-Question-and-Answering-models/blob/main/slightly_better.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# recommend T4GPU in colab  after model download it will work offline it will save model in folder
# prompt: create a json file

import json

data = [
    {
        "context": "The Mona Lisa is a half-length portrait painting by Italian artist Leonardo da Vinci. Considered an archetypal masterpiece of the Italian Renaissance, it has been described as 'the best known, the most visited, the most written about, the most sung about, the most parodied work of art in the world'.",
        "question": "Who painted the Mona Lisa?",
        "answers": {
            "text": ["Leonardo da Vinci"],
            "answer_start": [53]
        }
    },
    {
        "context": "The Amazon rainforest, also known in English as Amazonia, is a moist broadleaf tropical rainforest in the Amazon biome that covers most of the Amazon basin of South America. This basin encompasses 7,000,000 km2 (2,700,000 sq mi), of which 5,500,000 km2 (2,100,000 sq mi) are covered by the rainforest. This region includes territory belonging to nine nations.",
        "question": "How many nations does the Amazon rainforest region include?",
        "answers": {
            "text": ["nine"],
            "answer_start": [344]
        }
    },
    {
        "context": "The theory of relativity usually encompasses two interrelated theories by Albert Einstein: special relativity and general relativity. Special relativity applies to all physical phenomena in the absence of gravity. General relativity explains the law of gravitation and its relation to other forces of nature.",
        "question": "Who developed the theory of relativity?",
        "answers": {
            "text": ["Albert Einstein"],
            "answer_start": [81]
        }
    },
    {
        "context": "Python is an interpreted, high-level and general-purpose programming language. Python's design philosophy emphasizes code readability with its notable use of significant indentation. Its language constructs and object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.",
        "question": "What type of programming language is Python?",
        "answers": {
            "text": ["interpreted, high-level and general-purpose programming language"],
            "answer_start": [10]
        }
    },
    {
        "context": "The Great Wall of China is a series of fortifications that were built across the historical northern borders of ancient Chinese states and Imperial China as protection against various nomadic groups. Several walls were built from as early as the 7th century BC, with selective stretches later joined together by Qin Shi Huang, the first Emperor of China.",
        "question": "What was the purpose of the Great Wall of China?",
        "answers": {
            "text": ["protection against various nomadic groups"],
            "answer_start": [151]
        }
    },
    {
        "context": "The internet is a global system of interconnected computer networks that uses the Internet protocol suite (TCP/IP) to communicate between networks and devices. It is a network of networks that consists of private, public, academic, business, and government networks of local to global scope, linked by a broad array of electronic, wireless, and optical networking technologies.",
        "question": "What protocol suite does the internet use?",
        "answers": {
            "text": ["Internet protocol suite (TCP/IP)"],
            "answer_start": [75]
        }
    },
    {
        "context": "Electric cars are vehicles that are propelled by electric motors, which draw power from an onboard battery pack. Unlike traditional internal combustion engine vehicles, electric cars produce no tailpipe emissions, contributing to a reduction in urban air pollution.",
        "question": "What powers electric cars?",
        "answers": {
            "text": ["electric motors, which draw power from an onboard battery pack"],
            "answer_start": [47]
        }
    },
    {
        "context": "The Eiffel Tower is a wrought-iron lattice tower on the Champ de Mars in Paris, France. It is named after the engineer Gustave Eiffel, whose company designed and built the tower. Constructed from 1887 to 1889 as the entrance arch for the 1889 World's Fair, it was initially criticized by some of France's leading artists and intellectuals for its design, but it has become a global cultural icon of France and one of the most recognizable structures in the world.",
        "question": "Who designed the Eiffel Tower?",
        "answers": {
            "text": ["Gustave Eiffel"],
            "answer_start": [92]
        }
    },
    {
        "context": "Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy that can later be released to fuel the organisms' activities. This chemical energy is stored in carbohydrate molecules, such as sugars, which are synthesized from carbon dioxide and water. In most cases, oxygen is also released as a waste product.",
        "question": "What is the main purpose of photosynthesis?",
        "answers": {
            "text": ["to convert light energy into chemical energy"],
            "answer_start": [34]
        }
    },
    {
        "context": "Marie Curie was a Polish and naturalized-French physicist and chemist who conducted pioneering research on radioactivity. She was the first woman to win a Nobel Prize, the only woman to win the Nobel Prize twice, and the only person to win the Nobel Prize in two scientific fields.",
        "question": "What was Marie Curie known for?",
        "answers": {
            "text": ["pioneering research on radioactivity"],
            "answer_start": [85]
        }
    },
    {
        "context": "The Hubble Space Telescope is a large telescope in space. It was launched into orbit by space shuttle Discovery in 1990 and remains in operation. The Hubble telescope orbits Earth at an altitude of about 340 miles and takes pictures of planets, stars, and galaxies.",
        "question": "When was the Hubble Space Telescope launched?",
        "answers": {
            "text": ["1990"],
            "answer_start": [86]
        }
    },
    {
        "context": "Water is a transparent, tasteless, odorless, and nearly colorless chemical substance, which is the main constituent of Earth's hydrosphere and the fluids of all known living organisms. It is vital for all known forms of life, even though it provides no calories or organic nutrients.",
        "question": "What is the main constituent of Earth's hydrosphere?",
        "answers": {
            "text": ["Water"],
            "answer_start": [96]
        }
    },
    {
        "context": "The human brain is the central organ of the human nervous system, and with the spinal cord makes up the central nervous system. The brain consists of the cerebrum, the brainstem, and the cerebellum. It controls most of the activities of the body, processing, integrating, and coordinating the information it receives from the sense organs, and making decisions as to the instructions sent to the rest of the body.",
        "question": "What are the three main parts of the brain?",
        "answers": {
            "text": ["cerebrum, the brainstem, and the cerebellum"],
            "answer_start": [108]
        }
    },
    {
        "context": "Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass more than two and a half times that of all the other planets in the Solar System combined. Jupiter is primarily composed of hydrogen, but helium constitutes one quarter of its mass and one tenth of its volume.",
        "question": "What is Jupiter primarily composed of?",
        "answers": {
            "text": ["hydrogen"],
            "answer_start": [167]
        }
    },
    {
        "context": "The Great Barrier Reef is the world's largest coral reef system composed of over 2,900 individual reefs and 900 islands stretching for over 2,300 kilometers over an area of approximately 344,400 square kilometers. The reef is located in the Coral Sea, off the coast of Queensland, Australia.",
        "question": "Where is the Great Barrier Reef located?",
        "answers": {
            "text": ["in the Coral Sea, off the coast of Queensland, Australia"],
            "answer_start": [267]
        }
    },
    {
        "context": "The capital of France is Paris, which is known for its art, fashion, gastronomy, and culture. The 19th-century cityscape is crisscrossed by wide boulevards and the River Seine.",
        "question": "What is the capital of France?",
        "answers": {
            "text": ["Paris"],
            "answer_start": [21]
        }
    },
    {
        "context": "The cell is the basic structural, functional, and biological unit of all known organisms. A cell is the smallest unit of life. Cells are often called the 'building blocks of life'.",
        "question": "What is the basic unit of life?",
        "answers": {
            "text": ["cell"],
            "answer_start": [4]
        }
    },
    {
        "context": "The Pacific Ocean is the largest and deepest of Earth's oceanic divisions. It extends from the Arctic Ocean in the north to the Southern Ocean in the south and is bounded by Asia and Australia in the west and the Americas in the east.",
        "question": "What is the largest ocean on Earth?",
        "answers": {
            "text": ["Pacific Ocean"],
            "answer_start": [4]
        }
    },
    {
        "context": "Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy. This energy is stored in carbohydrate molecules, such as sugars, which are synthesized from carbon dioxide and water.",
        "question": "What do plants convert light energy into?",
        "answers": {
            "text": ["chemical energy"],
            "answer_start": [70]
        }
    },
    {
        "context": "The Battle of Gettysburg was a significant battle during the American Civil War, fought from July 1 to July 3, 1863. It resulted in a major victory for the Union and is often described as the war's turning point.",
        "question": "When was the Battle of Gettysburg fought?",
        "answers": {
            "text": ["from July 1 to July 3, 1863"],
            "answer_start": [81]
        }
    },
    {
        "context": "Mount Everest is Earth's highest mountain above sea level, located in the Mahalangur Himal sub-range of the Himalayas. The China-Nepal border runs across its summit point.",
        "question": "Where is Mount Everest located?",
        "answers": {
            "text": ["in the Mahalangur Himal sub-range of the Himalayas"],
            "answer_start": [57]
        }
    },
    {
        "context": "Albert Einstein was a theoretical physicist who developed the theory of relativity, one of the two pillars of modern physics. His work is also known for its influence on the philosophy of science.",
        "question": "What theory is Albert Einstein known for?",
        "answers": {
            "text": ["the theory of relativity"],
            "answer_start": [52]
        }
    },
    {
        "context": "The Great Wall of China is a series of fortifications made of stone, brick, tamped earth, wood, and other materials. It was built along the northern borders of China to protect against various nomadic groups from the Eurasian Steppe.",
        "question": "What was the primary purpose of the Great Wall of China?",
        "answers": {
            "text": ["to protect against various nomadic groups from the Eurasian Steppe"],
            "answer_start": [150]
        }
    },
    {
        "context": "The mitochondrion is a double-membrane-bound organelle found in most eukaryotic organisms. Mitochondria are often described as the powerhouses of the cell because they generate most of the cell's supply of adenosine triphosphate (ATP), used as a source of chemical energy.",
        "question": "What is the main function of mitochondria?",
        "answers": {
            "text": ["to generate most of the cell's supply of adenosine triphosphate (ATP)"],
            "answer_start": [137]
        }
    },
    {
        "context": "Shakespeare's play 'Romeo and Juliet' is a tragedy that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families.",
        "question": "What is the genre of Shakespeare's 'Romeo and Juliet'?",
        "answers": {
            "text": ["tragedy"],
            "answer_start": [37]
        }
    },
    {
        "context": "The Statue of Liberty is a colossal neoclassical sculpture on Liberty Island in New York Harbor. It was a gift from the people of France to the United States and is an icon of freedom and democracy.",
        "question": "Where is the Statue of Liberty located?",
        "answers": {
            "text": ["on Liberty Island in New York Harbor"],
            "answer_start": [45]
        }
    },
    {
        "context": "The Sahara is the largest hot desert in the world and the third largest desert overall after Antarctica and the Arctic. It is located in North Africa and covers large parts of Algeria, Chad, Egypt, Libya, Mali, Mauritania, Morocco, Niger, Western Sahara, Sudan, and Tunisia.",
        "question": "Where is the Sahara Desert located?",
        "answers": {
            "text": ["in North Africa"],
            "answer_start": [109]
        }
    },
    {
        "context": "The human heart is a muscular organ that pumps blood through the blood vessels of the circulatory system. It is located in the chest, between the lungs, and slightly to the left of the sternum.",
        "question": "Where is the human heart located?",
        "answers": {
            "text": ["in the chest, between the lungs, and slightly to the left of the sternum"],
            "answer_start": [86]
        }
    },
    {
        "context": "The Wright brothers, Orville and Wilbur, were American aviation pioneers generally credited with inventing, building, and flying the world's first successful motor-operated airplane. They made their first controlled, sustained flight of a powered, heavier-than-air aircraft on December 17, 1903.",
        "question": "Who invented the first successful airplane?",
        "answers": {
            "text": ["The Wright brothers, Orville and Wilbur"],
            "answer_start": [4]
        }
    },
    {
        "context": "The Nile is a major north-flowing river in northeastern Africa, and is commonly regarded as the longest river in the world. It runs through eleven countries, including Uganda, Sudan, and Egypt.",
        "question": "What is commonly regarded as the longest river in the world?",
        "answers": {
            "text": ["The Nile"],
            "answer_start": [4]
        }
    },
    {
        "context": "The Sydney Opera House is a multi-venue performing arts center in Sydney, Australia. It is one of the 20th century's most famous and distinctive buildings.",
        "question": "Where is the Sydney Opera House located?",
        "answers": {
            "text": ["Sydney, Australia"],
            "answer_start": [66]
        }
    },
    {
        "context": "The Amazon River is the largest river by discharge volume of water in the world, and by some definitions, it is the longest. It flows through Peru, Colombia, and Brazil.",
        "question": "Which countries does the Amazon River flow through?",
        "answers": {
            "text": ["Peru, Colombia, and Brazil"],
            "answer_start": [135]
        }
    },
    {
        "context": "The Pyramids of Giza are ancient pyramid structures in Egypt. They were built during the Fourth Dynasty of the Old Kingdom of Ancient Egypt. The largest of the pyramids was built for the Pharaoh Khufu.",
        "question": "For which Pharaoh was the largest pyramid of Giza built?",
        "answers": {
            "text": ["Pharaoh Khufu"],
            "answer_start": [138]
        }
    },
    {
        "context": "Newton's law of universal gravitation states that every point mass attracts every other point mass in the universe with a force that is directly proportional to the product of their masses and inversely proportional to the square of the distance between their centers.",
        "question": "What does Newton's law of universal gravitation state?",
        "answers": {
            "text": ["Every point mass attracts every other point mass in the universe with a force that is directly proportional to the product of their masses and inversely proportional to the square of the distance between their centers."],
            "answer_start": [0]
        }
    },
    {
        "context": "The Moon is Earth's only natural satellite and is the fifth largest satellite in the Solar System. It is the largest and most massive satellite of a planet relative to the planet it orbits.",
        "question": "What is Earth's only natural satellite?",
        "answers": {
            "text": ["The Moon"],
            "answer_start": [0]
        }
    },
    {
        "context": "The Colosseum is an oval amphitheatre in the centre of the city of Rome, Italy. Built of concrete and sand, it is the largest amphitheatre ever built and is considered one of the greatest works of architecture and engineering.",
        "question": "Where is the Colosseum located?",
        "answers": {
            "text": ["in the centre of the city of Rome, Italy"],
            "answer_start": [36]
        }
    },
    {
        "context": "The periodic table, also known as the periodic table of elements, is a tabular display of the chemical elements, organized by their atomic number, electron configuration, and recurring chemical properties. The structure of the table shows periodic trends.",
        "question": "What is the periodic table?",
        "answers": {
            "text": ["a tabular display of the chemical elements, organized by their atomic number, electron configuration, and recurring chemical properties"],
            "answer_start": [51]
        }
    },
    {
        "context": "Mars is the fourth planet from the Sun and the second-smallest planet in the Solar System, being larger than only Mercury. It is often referred to as the 'Red Planet' because the iron oxide prevalent on its surface gives it a reddish appearance.",
        "question": "Why is Mars often referred to as the 'Red Planet'?",
        "answers": {
            "text": ["because the iron oxide prevalent on its surface gives it a reddish appearance"],
            "answer_start": [156]
        }
    },
    {
        "context": "William Shakespeare was an English playwright, poet, and actor, widely regarded as the greatest writer in the English language and the world's greatest dramatist. His works include 39 plays, 154 sonnets, and two long narrative poems.",
        "question": "How many plays did William Shakespeare write?",
        "answers": {
            "text": ["39 plays"],
            "answer_start": [142]
        }
    },
    {
        "context": "The Richter scale, developed in 1935 by Charles F. Richter, is a logarithmic scale used to rate the magnitude of an earthquake, that is, the amount of energy released during an earthquake.",
        "question": "What is the purpose of the Richter scale?",
        "answers": {
            "text": ["to rate the magnitude of an earthquake"],
            "answer_start": [75]
        }
    },
    {
        "context": "The Golden Gate Bridge is a suspension bridge spanning the Golden Gate, the one-mile-wide strait connecting San Francisco Bay and the Pacific Ocean. The structure links the American city of San Francisco, California to Marin County.",
        "question": "What does the Golden Gate Bridge connect?",
        "answers": {
            "text": ["San Francisco Bay and the Pacific Ocean"],
            "answer_start": [82]
        }
    },
    {
        "context": "Nikola Tesla was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist who is best known for his contributions to the design of the modern alternating current (AC) electricity supply system.",
        "question": "What is Nikola Tesla best known for?",
        "answers": {
            "text": ["his contributions to the design of the modern alternating current (AC) electricity supply system"],
            "answer_start": [118]
        }
    },
    {
        "context": "The Renaissance was a fervent period of European cultural, artistic, political, and economic 'rebirth' following the Middle Ages. It promoted the rediscovery of classical philosophy, literature, and art.",
        "question": "What was the Renaissance?",
        "answers": {
            "text": ["a fervent period of European cultural, artistic, political, and economic 'rebirth' following the Middle Ages"],
            "answer_start": [20]
        }
    },
    {
        "context": "Mount Kilimanjaro is a dormant volcano in Tanzania. It has three volcanic cones: Kibo, Mawenzi, and Shira. It is the highest mountain in Africa and rises approximately 4,900 meters from its base to 5,895 meters above sea level.",
        "question": "What are the three volcanic cones of Mount Kilimanjaro?",
        "answers": {
            "text": ["Kibo, Mawenzi, and Shira"],
            "answer_start": [63]
        }
    },
    {
        "context": "The DNA molecule is composed of two strands that coil around each other to form a double helix. It carries genetic instructions for the development, functioning, growth, and reproduction of all known organisms and many viruses.",
        "question": "What is the structure of the DNA molecule?",
        "answers": {
            "text": ["a double helix"],
            "answer_start": [53]
        }
    }
]


with open("data.json", "w") as outfile:
    json.dump(data, outfile)

# %%
! pip install datasets

# %%
import json
from datasets import load_dataset, Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer
import torch

# Load the JSON data directly
with open('data.json', 'r') as f:
    data = json.load(f)

# Create a DatasetDict from the loaded data
dataset = DatasetDict({
    'train': Dataset.from_dict({
        'context': [item['context'] for item in data],
        'question': [item['question'] for item in data],
        'answers': [item['answers'] for item in data]
    })
})

# Tokenize
model_name = "distilbert-base-uncased-distilled-squad"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=512,
        truncation="only_second",
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length"
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answers = examples["answers"][sample_idx]
        start_char = answers["answer_start"][0]
        end_char = start_char + len(answers["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Finding the start and end of the context
        context_start = 0
        while sequence_ids[context_start] != 1:
            context_start += 1
        context_end = context_start
        while context_end < len(sequence_ids) and sequence_ids[context_end] == 1:
            context_end += 1
        context_end -= 1

        # Adjust start and end positions based on token offsets
        token_start_index = context_start
        while token_start_index <= context_end and offset[token_start_index][0] <= start_char:
            token_start_index += 1
        start_positions.append(token_start_index - 1)

        token_end_index = context_end
        while token_end_index >= context_start and offset[token_end_index][1] >= end_char:
            token_end_index -= 1
        end_positions.append(token_end_index + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

tokenized_datasets = dataset.map(preprocess_function, batched=True, remove_columns=dataset["train"].column_names)

model = AutoModelForQuestionAnswering.from_pretrained(model_name)

# Changes for dependence and training
training_args = TrainingArguments(
    output_dir="./results_more_training",
    learning_rate=5e-5,                  # Slightly higher learning rate
    per_device_train_batch_size=8,       # Commonly <16
    num_train_epochs=20,                 # exposure
    weight_decay=0.0,
    dataloader_drop_last=True,
    seed=42,                             # Set a seed for reproducibility
    report_to="none",                    # Disable W&B logging
    logging_steps=50,                    # frequently to observe training progress
    save_steps=1000,                     # Save checkpoints
    save_total_limit=2,                  #  n.of saved checkpoints
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    tokenizer=tokenizer,
)

trainer.train()

# Saving the updated and trained model
model.save_pretrained("./fine-tuned-model-more-training") # Save to a new directory
tokenizer.save_pretrained("./fine-tuned-model-more-training")

# %%
model = AutoModelForQuestionAnswering.from_pretrained("./fine-tuned-model")
tokenizer = AutoTokenizer.from_pretrained("./fine-tuned-model")

def answer_question(context, question):
    inputs = tokenizer(
        question,
        context,
        add_special_tokens=True,
        return_tensors="pt",
        max_length=512,  # Can adjust context size
        truncation=True
    )
    input_ids = inputs["input_ids"].tolist()[0]
    text_tokens = tokenizer.convert_ids_to_tokens(input_ids)

    with torch.no_grad():
        outputs = model(**inputs)

    answer_start = torch.argmax(outputs.start_logits)
    answer_end = torch.argmax(outputs.end_logits) + 1
    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))

    return answer

# tested on two or three sets only
context = (
    "Python is an interpreted, high-level and general-purpose programming language. Python's design philosophy "
    "emphasizes code readability with its notable use of significant indentation. Its language constructs and "
    "object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects."
)
question = "What is aim of python?"

answer = answer_question(context, question)
print(f"Question: {question}")
print(f"Answer: {answer}") #slightly better answer

# %%
# better answer increase the training file size
# working...

# %% [markdown]
# additional not important ⇓

# %%
import json
from datasets import Dataset, DatasetDict

# Load the JSON data directly from the file
with open('data.json', 'r') as f:
    data = json.load(f)

# Create a DatasetDict from the loaded data
# Assuming the data is for the training split, if you have validation/test data,
# you would need to structure the 'data' dictionary accordingly.
dataset = DatasetDict({
    'train': Dataset.from_dict({
        'context': [item['context'] for item in data],
        'question': [item['question'] for item in data],
        'answers': [item['answers'] for item in data]
    })
})

# If you need to split the dataset into train and test/validation sets:
# dataset = dataset['train'].train_test_split(test_size=0.2)
# dataset['validation'] = dataset.pop('test') # Rename test to validation if needed

# %%
from transformers import AutoTokenizer

model_name = "distilbert-base-uncased-distilled-squad"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length"
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = start_char + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)


        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1


        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:

            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

tokenized_datasets = dataset.map(preprocess_function, batched=True, remove_columns=dataset["train"].column_names)

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model = AutoModelForQuestionAnswering.from_pretrained(model_name)

training_args = TrainingArguments(
    output_dir="./results",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["train"],
    tokenizer=tokenizer,
)

trainer.train()

# %%
metrics = trainer.evaluate()
print(metrics)

# %%
model.save_pretrained("./fine-tuned-model")
tokenizer.save_pretrained("./fine-tuned-model")


model = AutoModelForQuestionAnswering.from_pretrained("./fine-tuned-model")
tokenizer = AutoTokenizer.from_pretrained("./fine-tuned-model")

# %%
! pip install torch

# %%
import torch

def answer_question(context, question):
    inputs = tokenizer(
        question,
        context,
        add_special_tokens=True,
        return_tensors="pt"
    )
    with torch.no_grad():
        outputs = model(**inputs)
    answer_start = torch.argmax(outputs.start_logits)
    answer_end = torch.argmax(outputs.end_logits) + 1
    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs.input_ids[0][answer_start:answer_end]))
    return answer


context = '''July 21: Belgian National Day (1831)
625 - Paulinus was consecrated as the first bishop of York by Justus, the archbishop of Canterbury.
1378 - Unrepresented labourers revolted and violently took over the government of the Republic of Florence (depicted), demanding that they be granted political office.
1946 - After weeks of unrest, rioters lynched Bolivian president Gualberto Villarroel, desecrating and hanging his corpse in the streets of La Paz.
1959 - The inaugural International Mathematical Olympiad, the leading mathematical competition for pre-university students, began in Romania.
1977 - Libyan forces carried out a raid at Sallum, sparking a four-day war with Egypt."'''
question = "What happened in Egypt?"

answer = answer_question(context, question)
print(f"Question: {question}")
print(f"Answer: {answer}")
